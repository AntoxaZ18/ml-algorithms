# %%
from pycaret.regression import *
import pandas as pd

# %%
df = pd.read_csv('Steel_industry_data.csv')

df.columns = df.columns.str.replace(' ', '_').str.lower()

df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y %H:%M')
df.set_index('date', inplace=True)

df.head()
# Out:
#                      usage_kwh  lagging_current_reactive.power_kvarh  \
# date
# 2018-01-01 00:15:00       3.17                                  2.95
# 2018-01-01 00:30:00       4.00                                  4.46
# 2018-01-01 00:45:00       3.24                                  3.28
# 2018-01-01 01:00:00       3.31                                  3.56
# 2018-01-01 01:15:00       3.82                                  4.50
#
#                      leading_current_reactive_power_kvarh  co2(tco2)  \
# date
# 2018-01-01 00:15:00                                   0.0        0.0
# 2018-01-01 00:30:00                                   0.0        0.0
# 2018-01-01 00:45:00                                   0.0        0.0
# 2018-01-01 01:00:00                                   0.0        0.0
# 2018-01-01 01:15:00                                   0.0        0.0
#
#                      lagging_current_power_factor  \
# date
# 2018-01-01 00:15:00                         73.21
# ...

# %%
s = setup(df, target='usage_kwh', session_id=42)
# Out:
# <style type="text/css">
# #T_50e8b_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_50e8b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_50e8b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_50e8b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50e8b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_50e8b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_50e8b_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_50e8b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_50e8b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_50e8b_row1_col1" class="data row1 col1" >usage_kwh</td>
#     </tr>
#     <tr>
#       <th id="T_50e8b_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()

# %%
evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
tuned_model = tune_model(best_model)
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              21:39:13
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# <style type="text/css">
# #T_0d4b9_row10_col0, #T_0d4b9_row10_col1, #T_0d4b9_row10_col2, #T_0d4b9_row10_col3, #T_0d4b9_row10_col4, #T_0d4b9_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_0d4b9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d4b9_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_0d4b9_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_0d4b9_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_0d4b9_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_0d4b9_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_0d4b9_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
# ...

# %%
predictions = predict_model(tuned_model, data=df)
# Out:
# <style type="text/css">
# </style>
# <table id="T_23231">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_23231_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_23231_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_23231_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_23231_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_23231_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_23231_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_23231_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23231_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_23231_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_23231_row0_col1" class="data row0 col1" >0.1073</td>
# ...

# %%
save_model(tuned_model, 'extra_tree_regressor')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['lagging_current_reactive.power_kvarh',
#                                               'leading_current_reactive_power_kvarh',
#                                               'co2(tco2)',
#                                               'lagging_current_power_factor',
#                                               'leading_current_power_factor',
#                                               'nsm'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['weekstatus', 'da...
#  Weekend    1
#  NaN       -1
#  dtype: int64}]))),
#                  ('onehot_encoding',
#                   TransformerWrapper(include=['day_of_week', 'load_type'],
# ...

# %%
import pandas as pd

df = pd.read_csv('model_metrics.csv')


df
# Out:
#                   Unnamed: 0  mean_absolute_error  mean_squared_error  \
# 0           LinearRegression             2.466609           18.770420
# 1                      Lasso             2.461997           18.759189
# 2        KNeighborsRegressor             2.174549           15.247844
# 3      DecisionTreeRegressor             1.942294           12.344406
# 4      RandomForestRegressor             2.119239           13.052926
# 5  GradientBoostingRegressor             2.007825           11.807350
#
#    mean_absolute_percentage_error  r2_score
# 0                        0.159133  0.980201
# 1                        0.157619  0.980213
# 2                        0.142985  0.983916
# 3                        0.120065  0.986979
# 4                        0.132648  0.986232
# 5                        0.146921  0.987546

# %% [markdown]
# Результаты работы алгоритма automl показывают более высокие метрики качества.
